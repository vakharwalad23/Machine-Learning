# %% [markdown]
# # Parts of Speech Tagging
#
# Parts of speech tagging (POS tagging or PoS tagging) is the process of assigning a part of speech to each word in a sentence, such as noun, verb, adjective, adverb, etc. This is a crucial step in natural language processing (NLP) as it helps in understanding the grammatical structure and meaning of the text.

# %% [markdown]
# ## POS Tags Reference
#
# **Coordinating & Conjunctions:**
# - **CC** - coordinating conjunction
# - **IN** - preposition/subordinating conjunction
#
# **Numbers & Determiners:**
# - **CD** - cardinal digit
# - **DT** - determiner
# - **PDT** - predeterminer (e.g., "all the kids")
#
# **Nouns:**
# - **NN** - noun, singular (e.g., "desk")
# - **NNS** - noun plural (e.g., "desks")
# - **NNP** - proper noun, singular (e.g., "Harrison")
# - **NNPS** - proper noun, plural (e.g., "Americans")
#
# **Pronouns:**
# - **PRP** - personal pronoun (I, he, she)
# - **PRP$** - possessive pronoun (my, his, hers)
# - **WP** - wh-pronoun (who, what)
# - **WP$** - possessive wh-pronoun (whose)
#
# **Adjectives:**
# - **JJ** - adjective (e.g., "big")
# - **JJR** - adjective, comparative (e.g., "bigger")
# - **JJS** - adjective, superlative (e.g., "biggest")
#
# **Adverbs:**
# - **RB** - adverb (very, silently)
# - **RBR** - adverb, comparative (better)
# - **RBS** - adverb, superlative (best)
# - **WRB** - wh-adverb (where, when)
#
# **Verbs:**
# - **VB** - verb, base form (take)
# - **VBD** - verb, past tense (took)
# - **VBG** - verb, gerund/present participle (taking)
# - **VBN** - verb, past participle (taken)
# - **VBP** - verb, present, non-3rd person (take)
# - **VBZ** - verb, 3rd person singular present (takes)
#
# **Other:**
# - **EX** - existential there (e.g., "there is")
# - **FW** - foreign word
# - **LS** - list marker (1))
# - **MD** - modal (could, will)
# - **POS** - possessive ending (parent's)
# - **RP** - particle (give up)
# - **TO** - to (e.g., "to go")
# - **UH** - interjection (errrrrrrrm)
# - **WDT** - wh-determiner

# %%
corpus = """
I have three visions for India. In 3000 years of our history, people from all over the world have come and invaded us, captured our lands, conquered our minds. From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,the French, the Dutch, all of them came and looted us, took over what was ours. Yet we have not done this to any other nation. We have not conquered anyone. We have not grabbed their land, their culture, their history and tried to enforce our way of life on them. Why? Because we respect the freedom of others.That is why my first vision is that of freedom. I believe that India got its first vision of this in 1857, when we started the War of Independence. It is this freedom thatwe must protect and nurture and build on. If we are not free, no one will respect us.My second vision for India’s development. For fifty years we have been a developing nation.It is time we see ourselves as a developed nation. We are among the top 5 nations of the worldin terms of GDP. We have a 10 percent growth rate in most areas. Our poverty levels are falling.Our achievements are being globally recognised today. Yet we lack the self-confidence tosee ourselves as a developed nation, self-reliant and self-assured. Isn’t this incorrect?I have a third vision. India must stand up to the world. Because I believe that unless India stands up to the world, no one will respect us. Only strength respects strength. We must be strong not only as a military power but also as an economic power. Both must go hand-in-hand. My good fortune was to have worked with three great minds. Dr. Vikram Sarabhai of the Dept. of space, Professor Satish Dhawan, who succeeded him and Dr. Brahm Prakash, father of nuclear material.I was lucky to have worked with all three of them closely and consider this the great opportunity of my life. I see four milestones in my career.
"""

# %%
from nltk.tokenize import sent_tokenize

sentences = sent_tokenize(corpus)

# %%
sentences
# Out:
# ['\nI have three visions for India.',
#  'In 3000 years of our history, people from all over the world have come and invaded us, captured our lands, conquered our minds.',
#  'From Alexander onwards, the Greeks, the Turks, the Moguls, the Portuguese, the British,the French, the Dutch, all of them came and looted us, took over what was ours.',
#  'Yet we have not done this to any other nation.',
#  'We have not conquered anyone.',
#  'We have not grabbed their land, their culture, their history and tried to enforce our way of life on them.',
#  'Why?',
#  'Because we respect the freedom of others.That is why my first vision is that of freedom.',
#  'I believe that India got its first vision of this in 1857, when we started the War of Independence.',
#  'It is this freedom thatwe must protect and nurture and build on.',
#  'If we are not free, no one will respect us.My second vision for India’s development.',
# ...

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/dhruvsmac/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/dhruvsmac/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
for pos in range(len(sentences)):
    words = word_tokenize(sentences[pos])
    words = [word for word in words if word not in stopwords.words('english')]
    tagged = pos_tag(words)
    print(f"Sentence {pos+1}: {tagged}\n")
# Out:
# Sentence 1: [('I', 'PRP'), ('three', 'CD'), ('visions', 'NNS'), ('India', 'NNP'), ('.', '.')]
#
# Sentence 2: [('In', 'IN'), ('3000', 'CD'), ('years', 'NNS'), ('history', 'NN'), (',', ','), ('people', 'NNS'), ('world', 'NN'), ('come', 'VBP'), ('invaded', 'VBN'), ('us', 'PRP'), (',', ','), ('captured', 'VBD'), ('lands', 'NNS'), (',', ','), ('conquered', 'VBD'), ('minds', 'NNS'), ('.', '.')]
#
# Sentence 3: [('From', 'IN'), ('Alexander', 'NNP'), ('onwards', 'NNS'), (',', ','), ('Greeks', 'NNP'), (',', ','), ('Turks', 'NNP'), (',', ','), ('Moguls', 'NNP'), (',', ','), ('Portuguese', 'NNP'), (',', ','), ('British', 'NNP'), (',', ','), ('French', 'NNP'), (',', ','), ('Dutch', 'NNP'), (',', ','), ('came', 'VBD'), ('looted', 'JJ'), ('us', 'PRP'), (',', ','), ('took', 'VBD'), ('.', '.')]
#
# Sentence 4: [('Yet', 'RB'), ('done', 'VBN'), ('nation', 'NN'), ('.', '.')]
#
# Sentence 5: [('We', 'PRP'), ('conquered', 'VBD'), ('anyone', 'NN'), ('.', '.')]
#
# ...

# %%
test_str = "John is learning NLP with NLTK."

# %%
for word in word_tokenize(test_str):
    if word not in stopwords.words('english'):
        print(pos_tag([word]))
# Out:
# [('John', 'NNP')]
# [('learning', 'VBG')]
# [('NLP', 'NN')]
# [('NLTK', 'NN')]
# [('.', '.')]

# %%
for word in word_tokenize(test_str):
    print(pos_tag([word]))
# Out:
# [('John', 'NNP')]
# [('is', 'VBZ')]
# [('learning', 'VBG')]
# [('NLP', 'NN')]
# [('with', 'IN')]
# [('NLTK', 'NN')]
# [('.', '.')]
